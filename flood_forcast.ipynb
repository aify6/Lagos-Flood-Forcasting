# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading Data
df = pd.read_csv('/content/drive/MyDrive/lagos_weeather_data_13-05-2004_to_2024.csv')
df
# Out:
#         datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0     13/05/2004     31.7     28.2  30.0          38.9          32.6
# 1     14/05/2004     26.6     25.7  26.3          26.6          25.7
# 2     15/05/2004     25.1     25.1  25.1          25.1          25.1
# 3     16/05/2004     22.9     22.9  22.9          22.9          22.9
# 4     17/05/2004     31.4     25.1  28.6          38.7          25.1
# ...          ...      ...      ...   ...           ...           ...
# 7808  29/06/2024     31.0     23.9  27.1          37.7          23.9
# 7809  30/06/2024     31.2     25.0  27.8          39.5          25.0
# 7810  01/07/2024     32.0     25.0  27.9          40.5          25.0
# 7811  02/07/2024     30.0     24.0  26.9          37.2          24.0
# 7812  03/07/2024     27.1     24.0  25.4          29.9          24.0
#
#       feelslike   dew  humidity  precip  ...  severerisk              sunrise  \
# ...

# %%
#Brief overview of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813 entries, 0 to 7812
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          7813 non-null   object
#  1   tempmax           7477 non-null   float64
#  2   tempmin           7477 non-null   float64
#  3   temp              7477 non-null   float64
#  4   feelslikemax      7477 non-null   float64
#  5   feelslikemin      7477 non-null   float64
#  6   feelslike         7477 non-null   float64
#  7   dew               7477 non-null   float64
#  8   humidity          7477 non-null   float64
#  9   precip            7477 non-null   float64
#  10  precipprob        7477 non-null   float64
#  11  precipcover       7813 non-null   float64
#  12  preciptype        3662 non-null   object
#  13  snow              3928 non-null   float64
#  14  snowdepth         3923 non-null   float64
#  15  windgust          5876 non-null   float64
# ...

# %%
#View column names
df.columns
# Out:
# Index(['datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations',
#        'windspeedmax', 'windspeedmin'],
#       dtype='object')

# %%
#dropping columns with too many null valus and irrelevance
cols = ['windspeedmax', 'windspeedmin','feelslikemax',
       'feelslikemin', 'feelslike','preciptype', 'snow', 'snowdepth','description', 'icon', 'stations','windgust',
       'winddir','sunrise','sunset', 'moonphase','dew', 'visibility','solarradiation', 'solarenergy', 'uvindex', 'severerisk']

df.drop(columns=cols, axis=1, inplace=True)
df
# Out:
#         datetime  tempmax  tempmin  temp  humidity  precip  precipprob  \
# 0     13/05/2004     31.7     28.2  30.0      74.7     0.0         0.0
# 1     14/05/2004     26.6     25.7  26.3      97.5     0.0         0.0
# 2     15/05/2004     25.1     25.1  25.1     100.0     0.0         0.0
# 3     16/05/2004     22.9     22.9  22.9      95.8     0.0         0.0
# 4     17/05/2004     31.4     25.1  28.6      84.2     0.0         0.0
# ...          ...      ...      ...   ...       ...     ...         ...
# 7808  29/06/2024     31.0     23.9  27.1      87.1    12.0       100.0
# 7809  30/06/2024     31.2     25.0  27.8      86.2     3.0       100.0
# 7810  01/07/2024     32.0     25.0  27.9      84.6     6.9       100.0
# 7811  02/07/2024     30.0     24.0  26.9      85.9    13.6       100.0
# 7812  03/07/2024     27.1     24.0  25.4      93.1    52.1       100.0
#
#       precipcover  windspeed  sealevelpressure  cloudcover  \
# ...

# %%
#Find duplicate values
df.duplicated()
df.drop_duplicates()
print(df.shape)
# Out:
# (7813, 12)

# %%
#Checking for missing values and handling them
df.isna().sum()
# Out:
# datetime              0
# tempmax             336
# tempmin             336
# temp                336
# humidity            336
# precip              336
# precipprob          336
# precipcover           0
# windspeed           366
# sealevelpressure    521
# cloudcover          336
# conditions          692
# dtype: int64

# %%
# Convert the 'datetime' column to datetime datatype, handling mixed formats
df['datetime'] = pd.to_datetime(df['datetime'], dayfirst=True)

# Set the 'datetime' column as the index
df.set_index('datetime', inplace=True)

# %%
# Create day, month, and year features from the datetime index
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year

# %%
# Drop rows where more than half of it are null values
df = df.dropna(thresh=len(df.columns) // 2 + 1)

# %%
# Fill missing values with the mean of the respective columns for numeric columns only
numeric_cols = df.select_dtypes(include=['number']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
#Encode the categorical variable condition
df['conditions'].unique()
# Out:
# array(['Partially cloudy', 'Rain, Partially cloudy', 'Rain, Overcast',
#        'Overcast', 'Clear', nan, 'Rain'], dtype=object)

# %%
#forward fill the conitions columns for nan values
df['conditions'].fillna(method='ffill', inplace=True)

# %%
map = {'Partially cloudy':2, 'Rain, Partially cloudy':5, 'Overcast':3,
       'Rain, Overcast':6, 'Clear':1, 'Rain':4}

df['conditions'] = df['conditions'].replace(map)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7477 entries, 2004-05-13 to 2024-07-03
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           7477 non-null   float64
#  1   tempmin           7477 non-null   float64
#  2   temp              7477 non-null   float64
#  3   humidity          7477 non-null   float64
#  4   precip            7477 non-null   float64
#  5   precipprob        7477 non-null   float64
#  6   precipcover       7477 non-null   float64
#  7   windspeed         7477 non-null   float64
#  8   sealevelpressure  7477 non-null   float64
#  9   cloudcover        7477 non-null   float64
#  10  conditions        7477 non-null   int64
#  11  day               7477 non-null   int32
#  12  month             7477 non-null   int32
#  13  year              7477 non-null   int32
# dtypes: float64(10), int32(3), int64(1)
# memory usage: 788.6 KB

# %%
#Basic statistics
df.describe()
# Out:
#            tempmax      tempmin         temp     humidity       precip  \
# count  7477.000000  7477.000000  7477.000000  7477.000000  7477.000000
# mean     31.299331    24.440631    27.449325    82.607155     5.139441
# std       2.586243     1.898043     1.581360     7.268018    18.322849
# min      21.400000    10.000000    21.400000    33.800000     0.000000
# 25%      29.100000    23.200000    26.200000    80.200000     0.000000
# 50%      31.500000    24.200000    27.400000    83.600000     0.000000
# 75%      33.100000    25.600000    28.600000    86.600000     2.000000
# max      56.000000    34.600000    34.600000   100.000000   299.000000
#
#         precipprob  precipcover    windspeed  sealevelpressure   cloudcover  \
# count  7477.000000  7477.000000  7477.000000       7477.000000  7477.000000
# mean     44.469707     5.536465    23.456801       1012.036779    59.849124
# std      49.696541    13.228048    11.530844          1.784510    16.710426
# ...

# %%
# Import necessary libraries
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Assuming 'tempmax' is the time series you want to analyze
# You might need to adjust this based on your data and analysis goals
series = df['precip']

# Seasonal Decomposition
result = seasonal_decompose(series, model='additive', period=365)  # Adjust period if needed

# Plot the decomposition
result.plot()
plt.show()

# %%
# Augmented Dickey-Fuller Test for Stationarity
def adf_test(timeseries):
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

adf_test(series)


# Autocorrelation and Partial Autocorrelation Plots
plot_acf(series, lags=50) # Adjust lags if needed
plt.show()
plot_pacf(series, lags=50) # Adjust lags if needed
plt.show()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.133903e+01
# p-value                        1.065868e-20
# #Lags Used                     2.700000e+01
# Number of Observations Used    7.449000e+03
# Critical Value (1%)           -3.431228e+00
# Critical Value (5%)           -2.861928e+00
# Critical Value (10%)          -2.566977e+00
# dtype: float64

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#dropping colinear variables
col = ['tempmax', 'tempmin']
df.drop(columns=col, axis=1, inplace=True)
df
# Out:
#             temp  humidity  precip  precipprob  precipcover  windspeed  \
# datetime
# 2004-05-13  30.0      74.7     0.0         0.0         0.00       20.5
# 2004-05-14  26.3      97.5     0.0         0.0         0.00       20.5
# 2004-05-15  25.1     100.0     0.0         0.0         0.00       16.6
# 2004-05-16  22.9      95.8     0.0         0.0         0.00       11.2
# 2004-05-17  28.6      84.2     0.0         0.0         0.00       31.3
# ...          ...       ...     ...         ...          ...        ...
# 2024-06-29  27.1      87.1    12.0       100.0         4.17       22.3
# 2024-06-30  27.8      86.2     3.0       100.0         4.17       25.9
# 2024-07-01  27.9      84.6     6.9       100.0        50.00       22.3
# 2024-07-02  26.9      85.9    13.6       100.0        62.50       22.7
# 2024-07-03  25.4      93.1    52.1       100.0        79.17       25.2
#
#             sealevelpressure  cloudcover  conditions  day  month  year
# datetime
# ...

# %%
# Create lag features for precip
for lag in range(1, 8):  # Create lag features from 1 to 7 days
    df[f'precip_lag_{lag}'] = df['precip'].shift(lag)

df['precip_ma7'] = df['precip'].rolling(window=7).mean()  # 7-day moving average
# Drop rows with NaN values due to lagging
df.dropna(inplace=True)

# %%
# Plot the time series
plt.figure(figsize=(10,6))
plt.plot(df['precip'])
plt.title('Precipitation Over Time')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Separate features and target
X = df.drop('precip', axis=1)
y = df['precip']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False, random_state = 7)

# %%
# Initialize the Linear Regression model
linear_model = LinearRegression()

# Fit the model
linear_model.fit(X_train, y_train)

# Predict on the test set
y_pred_linear = linear_model.predict(X_test)

# Calculate evaluation metrics
mse_linear = mean_squared_error(y_test, y_pred_linear)
mae_linear = mean_absolute_error(y_test, y_pred_linear)

# Print results
print('Linear Regression Model')
print(f'MSE: {mse_linear:.2f}')
print(f'MAE: {mae_linear:.2f}')
print()
# Out:
# Linear Regression Model
# MSE: 0.00
# MAE: 0.00

# %%
print(y_pred_linear)
print(y_test)
# Out:
# [ 4.   2.7 88.  ...  6.9 13.6 52.1]
# datetime
# 2021-08-31     4.0
# 2021-09-01     2.7
# 2021-09-02    88.0
# 2021-09-03    75.0
# 2021-09-04     0.0
#               ...
# 2024-06-29    12.0
# 2024-06-30     3.0
# 2024-07-01     6.9
# 2024-07-02    13.6
# 2024-07-03    52.1
# Name: precip, Length: 1494, dtype: float64

# %%
# Initialize the Random Forest model
rf_model = RandomForestRegressor()

# Fit the model
rf_model.fit(X_train, y_train)

# Predict on the test set
y_pred_rf = rf_model.predict(X_test)

# Calculate evaluation metrics
mse_rf = mean_squared_error(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)

# Print results
print('Random Forest Regression Model')
print(f'MSE: {mse_rf:.2f}')
print(f'MAE: {mae_rf:.2f}')
print()
# Out:
# Random Forest Regression Model
# MSE: 97.78
# MAE: 4.04

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Initialize the Decision Tree model
dt_model = DecisionTreeRegressor()

# Fit the model
dt_model.fit(X_train, y_train)

# Predict on the test set
y_pred_dt = dt_model.predict(X_test)

# Calculate evaluation metrics
mse_dt = mean_squared_error(y_test, y_pred_dt)
mae_dt = mean_absolute_error(y_test, y_pred_dt)

# Print results
print('Decision Tree Regression Model')
print(f'MSE: {mse_dt:.2f}')
print(f'MAE: {mae_dt:.2f}')
print()
# Out:
# Decision Tree Regression Model
# MSE: 147.65
# MAE: 4.49

# %%
# Initialize the SVR model
svr_model = SVR()

# Fit the model
svr_model.fit(X_train, y_train)

# Predict on the test set
y_pred_svr = svr_model.predict(X_test)

# Calculate evaluation metrics
mse_svr = mean_squared_error(y_test, y_pred_svr)
mae_svr = mean_absolute_error(y_test, y_pred_svr)

# Print results
print('Support Vector Regressor (SVR) Model')
print(f'MSE: {mse_svr:.2f}')
print(f'MAE: {mae_svr:.2f}')
print()
# Out:
# Support Vector Regressor (SVR) Model
# MSE: 228.02
# MAE: 4.67

# %%
# Initialize the XGBoost model
xgb_model = XGBRegressor()

# Fit the model
xgb_model.fit(X_train, y_train)

# Predict on the test set
y_pred_xgb = xgb_model.predict(X_test)

# Calculate evaluation metrics
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)

# Print results
print('XGBoost Regression Model')
print(f'MSE: {mse_xgb:.2f}')
print(f'MAE: {mae_xgb:.2f}')
print()
# Out:
# XGBoost Regression Model
# MSE: 37.73
# MAE: 2.48

# %%
# Predict future precipitation values
future_dates = pd.date_range(start=df.index[-1], periods=501)
future_dates = future_dates[1:]
future_data = pd.DataFrame(index=future_dates)


#include other features
future_data['temp'] = df['temp'][-500:].values
future_data['humidity'] = df['humidity'][-500:].values
future_data['precipprob'] = df['precipprob'][-500:].values
future_data['precipcover'] = df['precipcover'][-500:].values
future_data['windspeed'] = df['windspeed'][-500:].values
future_data['sealevelpressure'] = df['sealevelpressure'][-500:].values
future_data['cloudcover'] = df['cloudcover'][-500:].values
future_data['conditions'] = df['conditions'][-500:].values
future_data['day'] = future_dates.day
future_data['month'] = future_dates.month
future_data['year'] = future_dates.year

# Generate lag features for the future period
for lag in range(1, 8):
    future_data[f'precip_lag_{lag}'] = df['precip'].shift(lag)[-500:].values

# Check for and handle duplicate dates in the original DataFrame
if not df.index.is_unique:
    df = df[~df.index.duplicated(keep='first')]  # Keep the first occurrence of duplicate dates

future_data['precip_ma7'] = df['precip'].rolling(window=7).mean()[-500:].values # align the rolling mean with future_data

# %%
# Predict using the Linear Regression model
y_pred_xgb_future = xgb_model.predict(future_data)

# %%
# Create a DataFrame for the forecasted values
forecast_df = pd.DataFrame({'Forecast': y_pred_xgb_future}, index=future_dates)
forecast_df
# Out:
#              Forecast
# 2024-07-04   0.003038
# 2024-07-05   0.003038
# 2024-07-06   0.003038
# 2024-07-07   0.003849
# 2024-07-08   0.265326
# ...               ...
# 2025-11-11   9.447270
# 2025-11-12   9.463208
# 2025-11-13   4.469609
# 2025-11-14  15.846448
# 2025-11-15  25.560112
#
# [500 rows x 1 columns]

# %%
# Plot the forecast
plt.figure(figsize=(10, 6))
plt.plot(df['precip'], label='Observed')
plt.plot(forecast_df, label='Forecast', color='red')
plt.title('Precipitation Forecast')
plt.xlabel('Date')
plt.ylabel('Precipitation')
plt.legend()
plt.show()

# %%
def determine_flood_risk(predicted_precipitation, low_risk_threshold=10, moderate_risk_threshold=30, high_risk_threshold=50):
    risk = []
    for precip in predicted_precipitation:
        if precip > high_risk_threshold:
            risk.append(3)  # High risk
        elif precip > moderate_risk_threshold:
            risk.append(2)  # Moderate risk
        elif precip > low_risk_threshold:
            risk.append(1)  # Low risk
        else:
            risk.append(0)  # No risk
    return risk

# %%
forecast_df['flood_risk'] = determine_flood_risk(forecast_df['Forecast'])
forecast_df
# Out:
#              Forecast  flood_risk
# 2024-07-04   0.003038           0
# 2024-07-05   0.003038           0
# 2024-07-06   0.003038           0
# 2024-07-07   0.003849           0
# 2024-07-08   0.265326           0
# ...               ...         ...
# 2025-11-11   9.447270           0
# 2025-11-12   9.463208           0
# 2025-11-13   4.469609           0
# 2025-11-14  15.846448           1
# 2025-11-15  25.560112           1
#
# [500 rows x 2 columns]

# %%
from multiprocessing.context import ForkServerContext
# Filter and print days with flood risk level 3
high_risk_days = forecast_df[forecast_df['flood_risk'] == 3].index

print("Days with High Flood Risk (Flood Risk Level 3):")
for day in high_risk_days:
    print(day.strftime('%Y-%m-%d'))  # Print in 'YYYY-MM-DD' format
# Out:
# Days with High Flood Risk (Flood Risk Level 3):
# 2024-09-08
# 2024-09-26
# 2024-09-29
# 2024-10-20
# 2024-10-27
